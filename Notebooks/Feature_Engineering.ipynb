# %% [markdown]
# Handling inbalanced data.
# suppose a data having a  column whose value is in form of "YES" AND "NO".
# Suppose value of total count of YES is=900 out of 1000.
# and value  of NO is 100 out of 1000.
# to maintain this using pythomn we plot more No points to balace the data.
#
#  This done by putting more NO points on existing No points.
#  this does not effect the variance.

# %% [markdown]
# ## SMOTE(Synthetic Minority Oversampling Technique)
# SMOTE (Synthetic Minority Over-sampling Technique) is a technique used in machine learning to address imbalanced datasets where the minority class has significantly fewer instances than the majority class. SMOTE involves generating synthetic instances of the minority class by interpolating between existing instances.
#
# New minority data(of same kind) is added between two minority points.
#
# this changes variance of data.

# %% [markdown]
# OUTLIER TREATMENT.

# %%
import numpy as np

def remove_outlier(col):
    """
    This function calculates the lower and upper bounds 
    for detecting outliers based on the IQR method.
    """
    Q1, Q3 = np.percentile(col, [25, 75])  # Compute Q1 and Q3
    IQR = Q3 - Q1  # Interquartile Range
    lower_range = Q1 - (1.5 * IQR)  # Lower bound
    upper_range = Q3 + (1.5 * IQR)  # Upper bound
    return lower_range, upper_range

# Process the DataFrame
for column in df.columns:
    if column == 'Heart-Att':  # Skip 'Heart-Att' column
        continue
    lr, ur = remove_outlier(df[column])  # Get bounds for the column
    # Cap values to the bounds
    df[column] = np.clip(df[column], lr, ur)

# %% [markdown]
# ![image.png](attachment:image.png)
