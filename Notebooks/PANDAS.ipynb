# %%
#### Pandas-DataFrame And Series
##columns_to_drop = ['Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21']
##df.drop(columns=columns_to_drop, inplace=True)

# %% [markdown]
# Pandas is a powerful data manipulation library in Python, widely used for data analysis and data cleaning. It provides two primary data structures: Series and DataFrame. A Series is a one-dimensional array-like object, while a DataFrame is a two-dimensional, size-mutable, and potentially heterogeneous tabular data structure with labeled axes (rows and columns).**bold text**

# %%
! pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd
import numpy as np

# %%
#series
data=np.arange(1,6,1)
print(data)
# Out:
# [1 2 3 4 5]

# %%
series=pd.Series(data)
print("pandas series:",series)
print(type(series))
# Out:
# pandas series: 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
#Series from  dictionary
data1={'a':1,'b':2,'c':3,'d':4}
series_of_dictionary=pd.Series(data1)
print(series_of_dictionary)
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
data2=[20,30,40]
index=['a','b','c']
pd.Series(data2,index=range(1,4,1))
# Out:
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
pd.Series(data2,index=index)
# Out:
# a    20
# b    30
# c    40
# dtype: int64

# %%
## Dataframe
## create a Dataframe from a dictionary oof list
data3={
    'Name':['Krish','John','Jack'],
    'Age':[25,30,45],
    'City':['Bangalore','New York','Florida']
}

df=pd.DataFrame(data3)
print(df)
print(type(df))
# Out:
#     Name  Age       City
# 0  Krish   25  Bangalore
# 1   John   30   New York
# 2   Jack   45    Florida
# <class 'pandas.core.frame.DataFrame'>

# %%
data4=[
    {'Name':'Krish','Age':32,'City':'Bangalore'},
    {'Name':'John','Age':34,'City':'Bangalore'},
    {'Name':'Bappy','Age':32,'City':'Bangalore'},
    {'Name':'JAck','Age':32,'City':'Bangalore'}

]
df2=pd.DataFrame(data4)
print(df2)
# Out:
#     Name  Age       City
# 0  Krish   32  Bangalore
# 1   John   34  Bangalore
# 2  Bappy   32  Bangalore
# 3   JAck   32  Bangalore

# %%
df3 = pd.read_csv(r'D:\Data_Analysis\Data\data.csv')

# %%
df3.head()
# Out:
#          Date Category  Value   Product  Sales Region
# 0  2023-01-01        A   28.0  Product1  754.0   East
# 1  2023-01-02        B   39.0  Product3  110.0  North
# 2  2023-01-03        C   32.0  Product2  398.0   East
# 3  2023-01-04        B    8.0  Product1  522.0   East
# 4  2023-01-05        B   26.0  Product3  869.0  North

# %%
df.tail()
# Out:
#     Name  Age       City
# 0  Krish   25  Bangalore
# 1   John   30   New York
# 2   Jack   45    Florida

# %%
df
# Out:
#     Name  Age       City
# 0  Krish   25  Bangalore
# 1   John   30   New York
# 2   Jack   45    Florida

# %%
df['Name']
# Out:
# 0    Krish
# 1     John
# 2     Jack
# Name: Name, dtype: object

# %%
df
# Out:
#     Name  Age       City
# 0  Krish   25  Bangalore
# 1   John   30   New York
# 2   Jack   45    Florida

# %%
df['Salary']=[50000,60000,70000]

# %%
df
# Out:
#     Name  Age       City  Salary
# 0  Krish   25  Bangalore   50000
# 1   John   30   New York   60000
# 2   Jack   45    Florida   70000

# %%
df.drop('Salary',axis=1,inplace =True) # axis=1--->based on columns.
#axis=0--->based on rows.

# %%
df
# Out:
#     Name  Age       City
# 0  Krish   25  Bangalore
# 1   John   30   New York
# 2   Jack   45    Florida

# %%
df3
# Out:
#           Date Category  Value   Product  Sales Region
# 0   2023-01-01        A   28.0  Product1  754.0   East
# 1   2023-01-02        B   39.0  Product3  110.0  North
# 2   2023-01-03        C   32.0  Product2  398.0   East
# 3   2023-01-04        B    8.0  Product1  522.0   East
# 4   2023-01-05        B   26.0  Product3  869.0  North
# 5   2023-01-06        B   54.0  Product3  192.0   West
# 6   2023-01-07        A   16.0  Product1  936.0   East
# 7   2023-01-08        C   89.0  Product1  488.0   West
# 8   2023-01-09        C   37.0  Product3  772.0   West
# 9   2023-01-10        A   22.0  Product2  834.0   West
# 10  2023-01-11        B    7.0  Product1  842.0  North
# 11  2023-01-12        B   60.0  Product2    NaN   West
# 12  2023-01-13        A   70.0  Product3  628.0  South
# 13  2023-01-14        A   69.0  Product1  423.0   East
# 14  2023-01-15        A   47.0  Product2  893.0   West
# 15  2023-01-16        C    NaN  Product1  895.0  North
# ...

# %%
print(df3.dtypes)
# Out:
# Date         object
# Category     object
# Value       float64
# Product      object
# Sales       float64
# Region       object
# dtype: object

# %%
print("statical_summary",df3.describe())
# Out:
# statical_summary            Value       Sales
# count  47.000000   46.000000
# mean   51.744681  557.130435
# std    29.050532  274.598584
# min     2.000000  108.000000
# 25%    27.500000  339.000000
# 50%    54.000000  591.500000
# 75%    70.000000  767.500000
# max    99.000000  992.000000

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# sales and Marketing are the colums.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# name ,age ,gender are axes in upper example.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df3.shape
# Out:
# (50, 6)

# %%
df3
# Out:
#           Date Category  Value   Product  Sales Region
# 0   2023-01-01        A   28.0  Product1  754.0   East
# 1   2023-01-02        B   39.0  Product3  110.0  North
# 2   2023-01-03        C   32.0  Product2  398.0   East
# 3   2023-01-04        B    8.0  Product1  522.0   East
# 4   2023-01-05        B   26.0  Product3  869.0  North
# 5   2023-01-06        B   54.0  Product3  192.0   West
# 6   2023-01-07        A   16.0  Product1  936.0   East
# 7   2023-01-08        C   89.0  Product1  488.0   West
# 8   2023-01-09        C   37.0  Product3  772.0   West
# 9   2023-01-10        A   22.0  Product2  834.0   West
# 10  2023-01-11        B    7.0  Product1  842.0  North
# 11  2023-01-12        B   60.0  Product2    NaN   West
# 12  2023-01-13        A   70.0  Product3  628.0  South
# 13  2023-01-14        A   69.0  Product1  423.0   East
# 14  2023-01-15        A   47.0  Product2  893.0   West
# 15  2023-01-16        C    NaN  Product1  895.0  North
# ...

# %%
df3.head()
# Out:
#          Date Category  Value   Product  Sales Region
# 0  2023-01-01        A   28.0  Product1  754.0   East
# 1  2023-01-02        B   39.0  Product3  110.0  North
# 2  2023-01-03        C   32.0  Product2  398.0   East
# 3  2023-01-04        B    8.0  Product1  522.0   East
# 4  2023-01-05        B   26.0  Product3  869.0  North

# %%
df3.tail()
# Out:
#           Date Category  Value   Product  Sales Region
# 45  2023-02-15        B   99.0  Product2  599.0   West
# 46  2023-02-16        B    6.0  Product1  938.0  South
# 47  2023-02-17        B   69.0  Product3  143.0   West
# 48  2023-02-18        C   65.0  Product3  182.0  North
# 49  2023-02-19        C   11.0  Product3  708.0  North

# %%
## Hndlling missing values
df3.isnull() #--->returns boolean value---if there is null value then --true ,else-->false
# Out:
#      Date  Category  Value  Product  Sales  Region
# 0   False     False  False    False  False   False
# 1   False     False  False    False  False   False
# 2   False     False  False    False  False   False
# 3   False     False  False    False  False   False
# 4   False     False  False    False  False   False
# 5   False     False  False    False  False   False
# 6   False     False  False    False  False   False
# 7   False     False  False    False  False   False
# 8   False     False  False    False  False   False
# 9   False     False  False    False  False   False
# 10  False     False  False    False  False   False
# 11  False     False  False    False   True   False
# 12  False     False  False    False  False   False
# 13  False     False  False    False  False   False
# 14  False     False  False    False  False   False
# 15  False     False   True    False  False   False
# 16  False     False  False    False  False   False
# ...

# %%
df3.isnull().any()
# Out:
# Date        False
# Category    False
# Value        True
# Product     False
# Sales        True
# Region      False
# dtype: bool

# %%
df3.isnull().sum()
# Out:
# Date        0
# Category    0
# Value       3
# Product     0
# Sales       4
# Region      0
# dtype: int64

# %%
df3_filled=df3.fillna(0)

# %%
df3_filled
# Out:
#           Date Category  Value   Product  Sales Region
# 0   2023-01-01        A   28.0  Product1  754.0   East
# 1   2023-01-02        B   39.0  Product3  110.0  North
# 2   2023-01-03        C   32.0  Product2  398.0   East
# 3   2023-01-04        B    8.0  Product1  522.0   East
# 4   2023-01-05        B   26.0  Product3  869.0  North
# 5   2023-01-06        B   54.0  Product3  192.0   West
# 6   2023-01-07        A   16.0  Product1  936.0   East
# 7   2023-01-08        C   89.0  Product1  488.0   West
# 8   2023-01-09        C   37.0  Product3  772.0   West
# 9   2023-01-10        A   22.0  Product2  834.0   West
# 10  2023-01-11        B    7.0  Product1  842.0  North
# 11  2023-01-12        B   60.0  Product2    0.0   West
# 12  2023-01-13        A   70.0  Product3  628.0  South
# 13  2023-01-14        A   69.0  Product1  423.0   East
# 14  2023-01-15        A   47.0  Product2  893.0   West
# 15  2023-01-16        C    0.0  Product1  895.0  North
# ...

# %%
df3_filled.isnull()
# Out:
#      Date  Category  Value  Product  Sales  Region
# 0   False     False  False    False  False   False
# 1   False     False  False    False  False   False
# 2   False     False  False    False  False   False
# 3   False     False  False    False  False   False
# 4   False     False  False    False  False   False
# 5   False     False  False    False  False   False
# 6   False     False  False    False  False   False
# 7   False     False  False    False  False   False
# 8   False     False  False    False  False   False
# 9   False     False  False    False  False   False
# 10  False     False  False    False  False   False
# 11  False     False  False    False  False   False
# 12  False     False  False    False  False   False
# 13  False     False  False    False  False   False
# 14  False     False  False    False  False   False
# 15  False     False  False    False  False   False
# 16  False     False  False    False  False   False
# ...

# %%
df3_filled.isnull().any()
# Out:
# Date        False
# Category    False
# Value       False
# Product     False
# Sales       False
# Region      False
# dtype: bool

# %%
df3_filled.isnull().sum()
# Out:
# Date        0
# Category    0
# Value       0
# Product     0
# Sales       0
# Region      0
# dtype: int64

# %%
## filling missing values with the mean of the column.
df3.isnull().any()
# Out:
# Date        False
# Category    False
# Value        True
# Product     False
# Sales        True
# Region      False
# dtype: bool

# %%
df3.isnull().sum()
# Out:
# Date        0
# Category    0
# Value       3
# Product     0
# Sales       4
# Region      0
# dtype: int64

# %%
#filling null values in value with mean of that column.
df3['new_value']=df3['Value'].fillna(df3['Value'].mean())

# %%
df3
# Out:
#           Date Category  Value   Product  Sales Region  new_value
# 0   2023-01-01        A   28.0  Product1  754.0   East  28.000000
# 1   2023-01-02        B   39.0  Product3  110.0  North  39.000000
# 2   2023-01-03        C   32.0  Product2  398.0   East  32.000000
# 3   2023-01-04        B    8.0  Product1  522.0   East   8.000000
# 4   2023-01-05        B   26.0  Product3  869.0  North  26.000000
# 5   2023-01-06        B   54.0  Product3  192.0   West  54.000000
# 6   2023-01-07        A   16.0  Product1  936.0   East  16.000000
# 7   2023-01-08        C   89.0  Product1  488.0   West  89.000000
# 8   2023-01-09        C   37.0  Product3  772.0   West  37.000000
# 9   2023-01-10        A   22.0  Product2  834.0   West  22.000000
# 10  2023-01-11        B    7.0  Product1  842.0  North   7.000000
# 11  2023-01-12        B   60.0  Product2    NaN   West  60.000000
# 12  2023-01-13        A   70.0  Product3  628.0  South  70.000000
# ...

# %%
df3.isnull().sum()
# Out:
# Date         0
# Category     0
# Value        3
# Product      0
# Sales        4
# Region       0
# new_value    0
# dtype: int64

# %%
df3['new_sales']=df3['Sales'].fillna(df3['Sales'].mean())

# %%
df3
# Out:
#           Date Category  Value   Product  Sales Region  new_value   new_sales
# 0   2023-01-01        A   28.0  Product1  754.0   East  28.000000  754.000000
# 1   2023-01-02        B   39.0  Product3  110.0  North  39.000000  110.000000
# 2   2023-01-03        C   32.0  Product2  398.0   East  32.000000  398.000000
# 3   2023-01-04        B    8.0  Product1  522.0   East   8.000000  522.000000
# 4   2023-01-05        B   26.0  Product3  869.0  North  26.000000  869.000000
# 5   2023-01-06        B   54.0  Product3  192.0   West  54.000000  192.000000
# 6   2023-01-07        A   16.0  Product1  936.0   East  16.000000  936.000000
# 7   2023-01-08        C   89.0  Product1  488.0   West  89.000000  488.000000
# 8   2023-01-09        C   37.0  Product3  772.0   West  37.000000  772.000000
# 9   2023-01-10        A   22.0  Product2  834.0   West  22.000000  834.000000
# 10  2023-01-11        B    7.0  Product1  842.0  North   7.000000  842.000000
# ...

# %%
df3['Median_Sales']=df3['Sales'].fillna(df3['Sales'].median())
#replacing null with meadian of that column.

# %%
df3
# Out:
#           Date Category  Value   Product  Sales Region  new_value   new_sales  \
# 0   2023-01-01        A   28.0  Product1  754.0   East  28.000000  754.000000
# 1   2023-01-02        B   39.0  Product3  110.0  North  39.000000  110.000000
# 2   2023-01-03        C   32.0  Product2  398.0   East  32.000000  398.000000
# 3   2023-01-04        B    8.0  Product1  522.0   East   8.000000  522.000000
# 4   2023-01-05        B   26.0  Product3  869.0  North  26.000000  869.000000
# 5   2023-01-06        B   54.0  Product3  192.0   West  54.000000  192.000000
# 6   2023-01-07        A   16.0  Product1  936.0   East  16.000000  936.000000
# 7   2023-01-08        C   89.0  Product1  488.0   West  89.000000  488.000000
# 8   2023-01-09        C   37.0  Product3  772.0   West  37.000000  772.000000
# 9   2023-01-10        A   22.0  Product2  834.0   West  22.000000  834.000000
# 10  2023-01-11        B    7.0  Product1  842.0  North   7.000000  842.000000
# ...

# %%
df3['Meadian_values']=df3['Value'].fillna(df3['Value'].median())
#replacing null with meadian of that column.

# %%
df3
# Out:
#           Date Category  Value   Product  Sales Region  new_value   new_sales  \
# 0   2023-01-01        A   28.0  Product1  754.0   East  28.000000  754.000000
# 1   2023-01-02        B   39.0  Product3  110.0  North  39.000000  110.000000
# 2   2023-01-03        C   32.0  Product2  398.0   East  32.000000  398.000000
# 3   2023-01-04        B    8.0  Product1  522.0   East   8.000000  522.000000
# 4   2023-01-05        B   26.0  Product3  869.0  North  26.000000  869.000000
# 5   2023-01-06        B   54.0  Product3  192.0   West  54.000000  192.000000
# 6   2023-01-07        A   16.0  Product1  936.0   East  16.000000  936.000000
# 7   2023-01-08        C   89.0  Product1  488.0   West  89.000000  488.000000
# 8   2023-01-09        C   37.0  Product3  772.0   West  37.000000  772.000000
# 9   2023-01-10        A   22.0  Product2  834.0   West  22.000000  834.000000
# 10  2023-01-11        B    7.0  Product1  842.0  North   7.000000  842.000000
# ...

# %%
df3.dtypes
# Out:
# Date               object
# Category           object
# Value             float64
# Product            object
# Sales             float64
# Region             object
# new_value         float64
# new_sales         float64
# Median_Sales      float64
# Meadian_values    float64
# dtype: object

# %%
##Renaming Columns..
df3=df3.rename(columns={'Product':'Product_Name'})
df3.head()
# Out:
#          Date Category  Value Product_Name  Sales Region  new_value  \
# 0  2023-01-01        A   28.0     Product1  754.0   East       28.0
# 1  2023-01-02        B   39.0     Product3  110.0  North       39.0
# 2  2023-01-03        C   32.0     Product2  398.0   East       32.0
# 3  2023-01-04        B    8.0     Product1  522.0   East        8.0
# 4  2023-01-05        B   26.0     Product3  869.0  North       26.0
#
#    new_sales  Median_Sales  Meadian_values
# 0      754.0         754.0            28.0
# 1      110.0         110.0            39.0
# 2      398.0         398.0            32.0
# 3      522.0         522.0             8.0
# 4      869.0         869.0            26.0

# %%
df3=df3.rename(columns={'Region':'Region_name'})
df3
# Out:
#           Date Category  Value Product_Name  Sales Region_name  new_value  \
# 0   2023-01-01        A   28.0     Product1  754.0        East  28.000000
# 1   2023-01-02        B   39.0     Product3  110.0       North  39.000000
# 2   2023-01-03        C   32.0     Product2  398.0        East  32.000000
# 3   2023-01-04        B    8.0     Product1  522.0        East   8.000000
# 4   2023-01-05        B   26.0     Product3  869.0       North  26.000000
# 5   2023-01-06        B   54.0     Product3  192.0        West  54.000000
# 6   2023-01-07        A   16.0     Product1  936.0        East  16.000000
# 7   2023-01-08        C   89.0     Product1  488.0        West  89.000000
# 8   2023-01-09        C   37.0     Product3  772.0        West  37.000000
# 9   2023-01-10        A   22.0     Product2  834.0        West  22.000000
# 10  2023-01-11        B    7.0     Product1  842.0       North   7.000000
# 11  2023-01-12        B   60.0     Product2    NaN        West  60.000000
# ...

# %%
df3.head()
# Out:
#          Date Category  Value Product_Name  Sales Region_name  new_value  \
# 0  2023-01-01        A   28.0     Product1  754.0        East       28.0
# 1  2023-01-02        B   39.0     Product3  110.0       North       39.0
# 2  2023-01-03        C   32.0     Product2  398.0        East       32.0
# 3  2023-01-04        B    8.0     Product1  522.0        East        8.0
# 4  2023-01-05        B   26.0     Product3  869.0       North       26.0
#
#    new_sales  Median_Sales  Meadian_values
# 0      754.0         754.0            28.0
# 1      110.0         110.0            39.0
# 2      398.0         398.0            32.0
# 3      522.0         522.0             8.0
# 4      869.0         869.0            26.0

# %%
df3['new_value']=df3['Value'].fillna(df3['Value'].mean()).astype(int)

# %%
df3
# Out:
#           Date Category  Value Product_Name  Sales Region_name  new_value  \
# 0   2023-01-01        A   28.0     Product1  754.0        East         28
# 1   2023-01-02        B   39.0     Product3  110.0       North         39
# 2   2023-01-03        C   32.0     Product2  398.0        East         32
# 3   2023-01-04        B    8.0     Product1  522.0        East          8
# 4   2023-01-05        B   26.0     Product3  869.0       North         26
# 5   2023-01-06        B   54.0     Product3  192.0        West         54
# 6   2023-01-07        A   16.0     Product1  936.0        East         16
# 7   2023-01-08        C   89.0     Product1  488.0        West         89
# 8   2023-01-09        C   37.0     Product3  772.0        West         37
# 9   2023-01-10        A   22.0     Product2  834.0        West         22
# 10  2023-01-11        B    7.0     Product1  842.0       North          7
# 11  2023-01-12        B   60.0     Product2    NaN        West         60
# ...

# %%
df3.dtypes
# Out:
# Date               object
# Category           object
# Value             float64
# Product_Name       object
# Sales             float64
# Region_name        object
# new_value           int64
# new_sales         float64
# Median_Sales      float64
# Meadian_values    float64
# dtype: object

# %%
df3=df3['Value'].astype(int) ### read error --Cannot convert non-finite values (NA or inf) to integer
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 df3=df3['Value'].astype(int) ### read error --Cannot convert non-finite values (NA or inf) to integer
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# ...

# %%
df3.isnull().any()
# Out:
# Date              False
# Category          False
# Value              True
# Product_Name      False
# Sales              True
# Region_name       False
# new_value         False
# new_sales         False
# median_Sales      False
# Meadian_values    False
# dtype: bool

# %%
df3.dtypes
# Out:
# Date               object
# Category           object
# Value             float64
# Product_Name       object
# Sales             float64
# Region_name        object
# new_value           int64
# new_sales         float64
# median_Sales      float64
# Meadian_values    float64
# dtype: object

# %%
# applying lambda function
df3['2x_of_Value']=df3['Value'].apply(lambda x:x*2)

# %%
df3
# Out:
#           Date Category  Value Product_Name  Sales Region_name  new_value  \
# 0   2023-01-01        A   28.0     Product1  754.0        East         28
# 1   2023-01-02        B   39.0     Product3  110.0       North         39
# 2   2023-01-03        C   32.0     Product2  398.0        East         32
# 3   2023-01-04        B    8.0     Product1  522.0        East          8
# 4   2023-01-05        B   26.0     Product3  869.0       North         26
# 5   2023-01-06        B   54.0     Product3  192.0        West         54
# 6   2023-01-07        A   16.0     Product1  936.0        East         16
# 7   2023-01-08        C   89.0     Product1  488.0        West         89
# 8   2023-01-09        C   37.0     Product3  772.0        West         37
# 9   2023-01-10        A   22.0     Product2  834.0        West         22
# 10  2023-01-11        B    7.0     Product1  842.0       North          7
# 11  2023-01-12        B   60.0     Product2    NaN        West         60
# ...

# %%
grouped_mean=df3.groupby('Product_Name')['new_value'].mean()

# %%
grouped_mean
# Out:
# Product_Name
# Product1    46.812500
# Product2    52.800000
# Product3    54.947368
# Name: new_value, dtype: float64

# %%
df3.head()
# Out:
#          Date Category  Value Product_Name  Sales Region_name  new_value  \
# 0  2023-01-01        A   28.0     Product1  754.0        East         28
# 1  2023-01-02        B   39.0     Product3  110.0       North         39
# 2  2023-01-03        C   32.0     Product2  398.0        East         32
# 3  2023-01-04        B    8.0     Product1  522.0        East          8
# 4  2023-01-05        B   26.0     Product3  869.0       North         26
#
#    new_sales  median_Sales  Meadian_values  2x_of_Value
# 0      754.0         754.0            28.0         56.0
# 1      110.0         110.0            39.0         78.0
# 2      398.0         398.0            32.0         64.0
# 3      522.0         522.0             8.0         16.0
# 4      869.0         869.0            26.0         52.0

# %%
grouped_median=df3.groupby('Category')['Value'].median()

# %%
grouped_median
# Out:
# Category
# A    45.0
# B    52.0
# C    65.0
# Name: Value, dtype: float64

# %%
group_sum = df3.groupby(['Category', 'Product_Name', 'Region_name'])['Value'].sum()

# %%
group_sum
# Out:
# Category  Product_Name  Region_name
# A         Product1      East           172.0
#                         West            62.0
#           Product2      East            24.0
#                         West           117.0
#           Product3      East           139.0
#                         South           70.0
#                         West            93.0
# B         Product1      East            23.0
#                         North            7.0
#                         South            6.0
#           Product2      West           219.0
#           Product3      North          127.0
#                         South           63.0
#                         West           173.0
# C         Product1      East            97.0
#                         North            2.0
#                         South           94.0
#                         West           184.0
#           Product2      East            32.0
#                         North          127.0
# ...

# %%
group_agg=df3.groupby('Region_name')['Value'].agg(['mean','sum'])

# %%
group_agg
# Out:
#                   mean     sum
# Region_name
# East         42.307692   550.0
# North        37.666667   339.0
# South        62.000000   496.0
# West         61.588235  1047.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# group_agg['mean'].plot(kind='hist', bins=20, title='mean')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# group_agg['sum'].plot(kind='hist', bins=20, title='sum')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# group_agg.plot(kind='scatter', x='mean', y='sum', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
### Merging and joining Dataframes
# Create sample DataFrames
df5 = pd.DataFrame({'Key': ['A', 'B', 'C'], 'Value1': [1, 2, 3]})
df6 = pd.DataFrame({'Key': ['A', 'B', 'D'], 'Value2': [4, 5, 6]})

# %%
df5
# Out:
#   Key  Value1
# 0   A       1
# 1   B       2
# 2   C       3

# %%
df6
# Out:
#   Key  Value2
# 0   A       4
# 1   B       5
# 2   D       6

# %%
## Merge Datafranme on the 'Key Columns'
pd.merge(df5,df2,on="Key",how="outer")
# Out:
#   Key  Value1  Value2
# 0   A     1.0     4.0
# 1   B     2.0     5.0
# 2   C     3.0     NaN
# 3   D     NaN     6.0

# %%
pd.merge(df5,df2,on="Key",how="inner")
# Out:
#   Key  Value1  Value2
# 0   A       1       4
# 1   B       2       5

# %%
pd.merge(df5,df2,on="Key",how="left")
# Out:
#   Key  Value1  Value2
# 0   A       1     4.0
# 1   B       2     5.0
# 2   C       3     NaN

# %%
pd.merge(df5,df2,on="Key",how="right")
# Out:
#   Key  Value1  Value2
# 0   A     1.0       4
# 1   B     2.0       5
# 2   D     NaN       6
